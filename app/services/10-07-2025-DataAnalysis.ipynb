# %%
import seaborn as sns
import pandas as pd
titanic = sns.load_dataset("titanic")

# %%
titanic.head()

# %%
titanic.columns

# %%
titanic.shape

# %%
titanic.dtypes

# %%
titanic['age'] = titanic['age'].astype('int')

# %%
titanic.isna().sum()

# %%
titanic['age'] = titanic['age'].fillna(0)

# %%
titanic.isna().sum()

# %%
titanic['age'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 titanic['age'].astype('int')
#
# File c:\Users\DhananjaiSingh\Desktop\PythonTutorials\.venv\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File c:\Users\DhananjaiSingh\Desktop\PythonTutorials\.venv\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
titanic.dtypes

# %%
pd.to_datetime()

# %%
titanic.isna().sum().sum()

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
new_df = titanic.drop(['sibsp','parch'], axis=1)

# %%
titanic.drop(['sibsp','parch'], axis=1, inplace=True)

# %%
new_df
# Out:
#      survived  pclass     sex   age     fare embarked   class    who  \
# 0           0       3    male  22.0   7.2500        S   Third    man
# 1           1       1  female  38.0  71.2833        C   First  woman
# 2           1       3  female  26.0   7.9250        S   Third  woman
# 3           1       1  female  35.0  53.1000        S   First  woman
# 4           0       3    male  35.0   8.0500        S   Third    man
# ..        ...     ...     ...   ...      ...      ...     ...    ...
# 886         0       2    male  27.0  13.0000        S  Second    man
# 887         1       1  female  19.0  30.0000        S   First  woman
# 888         0       3  female   NaN  23.4500        S   Third  woman
# 889         1       1    male  26.0  30.0000        C   First    man
# 890         0       3    male  32.0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age     fare embarked   class    who  \
# 0           0       3    male  22.0   7.2500        S   Third    man
# 1           1       1  female  38.0  71.2833        C   First  woman
# 2           1       3  female  26.0   7.9250        S   Third  woman
# 3           1       1  female  35.0  53.1000        S   First  woman
# 4           0       3    male  35.0   8.0500        S   Third    man
# ..        ...     ...     ...   ...      ...      ...     ...    ...
# 886         0       2    male  27.0  13.0000        S  Second    man
# 887         1       1  female  19.0  30.0000        S   First  woman
# 888         0       3  female   NaN  23.4500        S   Third  woman
# 889         1       1    male  26.0  30.0000        C   First    man
# 890         0       3    male  32.0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# ...

# %%
titanic.drop_duplicates()
# Out:
#      survived  pclass     sex   age     fare embarked  class    who  \
# 0           0       3    male  22.0   7.2500        S  Third    man
# 1           1       1  female  38.0  71.2833        C  First  woman
# 2           1       3  female  26.0   7.9250        S  Third  woman
# 3           1       1  female  35.0  53.1000        S  First  woman
# 4           0       3    male  35.0   8.0500        S  Third    man
# ..        ...     ...     ...   ...      ...      ...    ...    ...
# 885         0       3  female  39.0  29.1250        Q  Third  woman
# 887         1       1  female  19.0  30.0000        S  First  woman
# 888         0       3  female   NaN  23.4500        S  Third  woman
# 889         1       1    male  26.0  30.0000        C  First    man
# 890         0       3    male  32.0   7.7500        Q  Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# ...

# %%
titanic.drop_duplicates(subset = ['age'])
# Out:
#      survived  pclass     sex    age     fare embarked   class    who  \
# 0           0       3    male  22.00   7.2500        S   Third    man
# 1           1       1  female  38.00  71.2833        C   First  woman
# 2           1       3  female  26.00   7.9250        S   Third  woman
# 3           1       1  female  35.00  53.1000        S   First  woman
# 5           0       3    male    NaN   8.4583        Q   Third    man
# ..        ...     ...     ...    ...      ...      ...     ...    ...
# 755         1       2    male   0.67  14.5000        S  Second  child
# 767         0       3  female  30.50   7.7500        Q   Third  woman
# 803         1       3    male   0.42   8.5167        C   Third  child
# 843         0       3    male  34.50   6.4375        C   Third    man
# 851         0       3    male  74.00   7.7750        S   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# ...

# %%
df_age_30_female = titanic[(titanic['age'] >= 30) & (titanic['sex'] =='female')]

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age        fare embarked  class  \
# count   891.000000  891.000000   891  714.000000  891.000000      889    891
# unique         NaN         NaN     2         NaN         NaN        3      3
# top            NaN         NaN  male         NaN         NaN        S  Third
# freq           NaN         NaN   577         NaN         NaN      644    491
# mean      0.383838    2.308642   NaN   29.699118   32.204208      NaN    NaN
# std       0.486592    0.836071   NaN   14.526497   49.693429      NaN    NaN
# min       0.000000    1.000000   NaN    0.420000    0.000000      NaN    NaN
# 25%       0.000000    2.000000   NaN   20.125000    7.910400      NaN    NaN
# 50%       0.000000    3.000000   NaN   28.000000   14.454200      NaN    NaN
# 75%       1.000000    3.000000   NaN   38.000000   31.000000      NaN    NaN
# max       1.000000    3.000000   NaN   80.000000  512.329200      NaN    NaN
#
# ...

# %%
titanic['age_fare'] = titanic['age'] / titanic['fare']

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# age_fare       177
# dtype: int64

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# age_fare        float64
# dtype: object

# %%
titanic['sex_age'] =  titanic['sex'] + "_" +  titanic['age'].astype('str')

# %%
titanic
# Out:
#      survived  pclass     sex   age     fare embarked   class    who  \
# 0           0       3    male  22.0   7.2500        S   Third    man
# 1           1       1  female  38.0  71.2833        C   First  woman
# 2           1       3  female  26.0   7.9250        S   Third  woman
# 3           1       1  female  35.0  53.1000        S   First  woman
# 4           0       3    male  35.0   8.0500        S   Third    man
# ..        ...     ...     ...   ...      ...      ...     ...    ...
# 886         0       2    male  27.0  13.0000        S  Second    man
# 887         1       1  female  19.0  30.0000        S   First  woman
# 888         0       3  female   NaN  23.4500        S   Third  woman
# 889         1       1    male  26.0  30.0000        C   First    man
# 890         0       3    male  32.0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  age_fare      sex_age
# ...

# %%
titanic.nunique()
# Out:
# 88

# %%
titanic['age'].nunique()

# %%
titanic['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)
